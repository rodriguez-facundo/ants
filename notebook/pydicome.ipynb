# %%
import pydicom
from matplotlib import pyplot as plt

# %% [markdown]
# ## Plot single image

# %%
plt.imshow(pydicom.dcmread('dicom_pet/IM_00080.dcm').pixel_array, cmap=plt.cm.inferno)

# %% [markdown]
# ## Metadata

# %%
pydicom.dcmread('dicom_pet/IM_00012.dcm')
# Out:
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY']
# (0008, 0016) SOP Class UID                       UI: Positron Emission Tomography Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.826.0.1.3680043.2.962.1398401260.00012
# (0008, 0020) Study Date                          DA: '20070801'
# (0008, 0021) Series Date                         DA: '20070801'
# (0008, 0022) Acquisition Date                    DA: '20070801'
# (0008, 0023) Content Date                        DA: '20070801'
# (0008, 0030) Study Time                          TM: '103000.000000'
# (0008, 0031) Series Time                         TM: '103000.000000'
# (0008, 0032) Acquisition Time                    TM: '103000.000000'
# (0008, 0033) Content Time                        TM: '103000.000000'
# (0008, 0050) Accession Number                    SH: ''
# ...
